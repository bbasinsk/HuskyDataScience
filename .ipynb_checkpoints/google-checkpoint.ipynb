# %%
# %matplotlib inline
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use('ggplot') #makes the plot look nicer

# Lets use data from 2008 to now
start = datetime.datetime(2008, 1, 1)
end = datetime.datetime.now()

# Read in Google stock data from morningstar
# df = 'data frame'
df = web.DataReader("GOOGL", "morningstar", start, end)

# Sets the x-axis to the date (instead of the symbol)
df.reset_index(inplace=True)
df.set_index("Date", inplace=True)

# Let's look at the data in the past week
print(df.tail(7))
# Out:
#            Symbol    Close       High        Low     Open   Volume
# Date
# 2018-05-11  GOOGL  1103.38  1109.0100  1097.2200  1100.41  1525218
# 2018-05-14  GOOGL  1106.60  1118.1500  1104.8000  1105.57  1966893
# 2018-05-15  GOOGL  1084.87  1099.1200  1078.7800  1096.90  1786926
# 2018-05-16  GOOGL  1084.09  1094.3825  1081.6301  1085.09  1281406
# 2018-05-17  GOOGL  1081.26  1091.0000  1076.4200  1081.46  1286907
# 2018-05-18  GOOGL  1069.64  1073.7300  1064.6800  1066.00  1774149
# 2018-05-21  GOOGL  1084.01  1093.3000  1078.0000  1079.00  1258999

# %% [markdown]
# ## Let's plot the daily high points on a graph!

# %%
df['High'].plot() #Creates the line plot of the 'high' values
plt.show() #Displays the graph

# %%
# Let's save the data to a csv
df.to_csv('GoogleData.csv')
