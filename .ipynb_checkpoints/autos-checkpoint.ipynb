# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot') #makes the plot look nicer

# Let's read in the data and see what it looks like
df = pd.read_csv('autos.csv', encoding='latin-1')
print(df.head())
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %%
df = csv_data[['dateCrawled', 'name', 'price', 'model', 'yearOfRegistration', 'kilometer', 'powerPS']]
print(df.head())

df.reset_index(inplace=True)
df.set_index("dateCrawled", inplace=True)

#Now let's look at price vs power at 20% opacity
plt.scatter(df['price'], df['powerPS'], alpha=0.2)
# Out:
#            dateCrawled                            name  price  model  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6    480   golf
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  18300    NaN
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"   9800  grand
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER   1500   golf
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic   3600  fabia
#
#    yearOfRegistration  kilometer  powerPS
# 0                1993     150000        0
# 1                2011     125000      190
# 2                2004     125000      163
# 3                2001     150000       75
# 4                2008      90000       69

# %%
# Let's filter it down to cars that are less than 100k Euros = ~$120k USD
df = df[df['price'] < 100000]
plt.scatter(df['price'], df['powerPS'], alpha=0.2)

# %%
# And let's filter down to less than 800PS = 850HP
df = df[df['powerPS'] < 800]
plt.scatter(df['price'], df['powerPS'], alpha=0.2)

# %%
import numpy as np

# finds line of best fit (slope and y-intercept)
fit = np.polyfit(x=df['price'], y=df['powerPS'], deg=1)
m = fit[0]
b = fit[1]

# Same scatter plot
plt.scatter(df['price'], df['powerPS'], alpha=0.2)

# Add line of best fit (mx + b)
x = df['price']
y = m * x + b
plt.plot(x, y, color='black')

# %%
#What is the slope?
print(m)
# Out:
# 0.00507134477313

# %%
# On Average, for every 1000 Euros you put into a car, 
print(m * 1000)
# You get 5.07 more PS
# Out:
# 5.07134477313
